# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = False

# %%
dat=pd.read_table("PROJ3DAT.tsv")

# %%
dat.head()
# Out:
#        umag      gmag      rmag      imag      zmag         z  SVMPython  \
# 0  19.70310  17.84598  16.96168  16.57809  16.24854  0.078133          0
# 1  20.04080  18.16672  17.23735  16.79414  16.48813  0.082131          0
# 2  20.31891  18.48649  17.54473  17.04582  16.66733  0.083400          0
# 3  16.58005  15.46228  14.90894  14.63244  14.37353  0.020017          1
# 4  20.64431  18.51183  17.59260  17.17126  16.85818  0.082439          0
#
#    RFPython
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0

# %%
plt.hist(dat["z"])
plt.show()

# %%
plt.scatter(dat["z"],2**dat["rmag"],alpha=0.005)
plt.xlabel("Redshift")
plt.ylabel(r"$2^{m_r}$")
plt.show()
